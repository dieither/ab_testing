# %% [markdown]
# <a href="https://colab.research.google.com/github/dieither/ab_testing/blob/main/git_exapmle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test colab notebook
#
# this notebook was created to test github upload from google colab.

# %%
# simple test notebook for github upload

print("hello github from colab")

numbers = [1, 2, 3, 4, 5]

squared = [x**2 for x in numbers]

print("numbers:", numbers)
print("squared:", squared)
# Out:
# hello github from colab
# numbers: [1, 2, 3, 4, 5]
# squared: [1, 4, 9, 16, 25]
